# %%
import pandas as pd

# %%
obs=pd.read_csv('observation.csv')

# %%
obs
# Out:
#                         Email Address      First Name     Last Name Branch  \
# 0      kaushal.chaudhary.99@gmail.com         Kaushal     Chaudhary    ECE
# 1           mohit.dubey9718@gmail.com           Mohit         Dubey    ECE
# 2         kartikshandilya@paperwrk.in          Kartik     Shandilya    ECE
# 3           nigampraneet460@gmail.com         Praneet         Nigam    ECE
# 4         singh.santosh2702@gmail.com         Santosh         Kumar     CS
# 5                    17kssh@gmail.com          Kartik     Shandilya    ECE
# 6                 pknigam00@gmail.com         Praneet         Nigam    ECE
# 7        lakshaysharma10111@gmail.com         Lakshay        Sharma    ECE
# 8             purohitdeep05@gmail.com      Deep Kumar       Purohit    ECE
# 9             saroshjibreel@gmail.com          Sarosh           NaN    ECE
# 10            mayankgoel756@gmail.com          Mayank         Goyal     CS
# ...

# %%
obs.columns
# Out:
# Index(['Email Address', 'First Name', 'Last Name', 'Branch', 'Year',
#        'MEMBER_RATING', 'OPTIN_TIME', 'OPTIN_IP', 'CONFIRM_TIME', 'CONFIRM_IP',
#        'LATITUDE', 'LONGITUDE', 'GMTOFF', 'DSTOFF', 'TIMEZONE', 'CC', 'REGION',
#        'LAST_CHANGED', 'LEID', 'EUID', 'NOTES'],
#       dtype='object')

# %%
obs.drop(['Email Address', 'First Name', 'Last Name',
       'MEMBER_RATING', 'OPTIN_TIME', 'OPTIN_IP', 'CONFIRM_TIME', 'CONFIRM_IP',
       'LATITUDE', 'LONGITUDE', 'GMTOFF', 'DSTOFF', 'TIMEZONE', 'CC', 'REGION',
       'LAST_CHANGED', 'LEID', 'EUID', 'NOTES']
      , axis=1, inplace=True)

# %%
obs
# Out:
#     Branch    Year
# 0      ECE   Third
# 1      ECE   Third
# 2      ECE   Third
# 3      ECE   Third
# 4       CS  Second
# 5      ECE   Third
# 6      ECE   Third
# 7      ECE  Second
# 8      ECE   Third
# 9      ECE  Second
# 10      CS  Second
# 11      CS  Fourth
# 12      IT  Second
# 13      IT  Second
# 14      CS   Third
# 15     ECE  Fourth
# 16     ECE  Fourth
# 17      CS   Third
# 18      CS   Third
# 19     ECE   Third
# 20     ECE   Third
# 21      CS   Third
# 22     ECE  Second
# 23      IT  Second
# 24      CS  Second
# 25      CS   Third
# 26      CS   Third
# 27      IT  Second
# 28     ECE  Second
# 29      IT  Second
# ..     ...     ...
# 95      IT   Third
# 96      EN   Third
# 97      EN   Third
# 98     ECE   Third
# 99     ECE   Third
# 100    ECE   Third
# 101     IT  Second
# 102     CS   First
# 103     EN   Third
# 104    ECE  Second
# 105    ECE   Third
# 106    ECE  Second
# 107    ECE  Second
# 108    ECE  Second
# 109    ECE  Second
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
obs['Branch'].value_counts().plot.bar(figsize=(10,5), fontsize=16, title='Participants from different Departments')

# %%
obs['Year'].value_counts().plot.bar(figsize=(10,5), fontsize=16, title='Participants from different Year')
